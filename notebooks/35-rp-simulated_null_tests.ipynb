# %%
from pathlib import Path
import numpy as np
import sys, os

import numpy as np
from hyppo.independence import Dcorr
from hyppo.ksample._utils import k_sample_transform
from scipy.spatial.distance import squareform, pdist
import matplotlib.pyplot as plt
from matplotlib.legend import Legend
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../")
from src.tools.utils import get_files, get_latents
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('../data/2sample_tests/simulations/DCORR_restricted_perm_SIMULATED_datasets=500_dict_perm=100_min_rank-ZG3.pkl', 'rb') as handle:
    data_dict = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-e29169b4a8a5> in <module>
# ----> 1 with open('../data/2sample_tests/simulations/DCORR_restricted_perm_SIMULATED_datasets=500_dict_perm=100_min_rank-ZG3.pkl', 'rb') as handle:
#       2     data_dict = pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/2sample_tests/simulations/DCORR_restricted_perm_SIMULATED_datasets=500_dict_perm=100_min_rank-ZG3.pkl'

# %%
fig, axes = plt.subplots(len(data_dict.keys()),1,sharex=True, figsize=(4, 4*len(data_dict.keys())))
for ax,test in zip(axes, data_dict.keys()):
    ax.hist(data_dict[test])
    ax.set_title(f'i.e. {test}')
    ax.set_xlim(0,1)
for ax in axes[:-1]:
    ax.set_xticks([])
axes[-1].set_xlabel('pvalues')
#fig.suptitle('Distribution of simulated pvalues under restricted permutations', y=0.89)
# Out:
# Text(0.5, 0, 'pvalues')

# %%
with open('../data/2sample_tests/simulations/MGC_restricted_perm_SIMULATED_datasets=500_dict_perm=100_min_rank-ZG3.pkl', 'rb') as handle:
    data_dict = pickle.load(handle)

# %%
fig, axes = plt.subplots(len(data_dict.keys()),1,sharex=True, figsize=(4, 4*len(data_dict.keys())))
for ax,test in zip(axes, data_dict.keys()):
    ax.hist(data_dict[test], bins = np.arange(0,1.1,0.1))
    ax.set_title(f'i.e. {test}')
    ax.set_xlim(0,1)
for ax in axes[:-1]:
    ax.set_xticks([])
axes[-1].set_xlabel('pvalues')
axes[-1].set_xticks(np.arange(0,1.1,0.1))
#fig.suptitle('Distribution of simulated pvalues under restricted permutations', y=0.89)
plt.show()

# %%
with open('../data/2sample_tests/simulations/MGC_restricted-zeroed-centered_SIMULATED_datasets=500_dict_perm=100_min_rank-ZG3.pkl', 'rb') as handle:
    data_dict = pickle.load(handle)

# %%
fig, axes = plt.subplots(len(data_dict.keys()),1,sharex=True, figsize=(4, 4*len(data_dict.keys())))
for ax,test in zip(axes, data_dict.keys()):
    ax.hist(data_dict[test], bins = np.arange(0,1.1,0.1))
    ax.set_title(f'i.e. {test}')
    ax.set_xlim(0,1)
for ax in axes[:-1]:
    ax.set_xticks([])
axes[-1].set_xlabel('pvalues')
axes[-1].set_xticks(np.arange(0,1.1,0.1))
plt.show()
